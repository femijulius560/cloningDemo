# %% [markdown]
# # 🎉 Welcome to Your Cloned Repo!
# You've successfully cloned this project into VS Code.
#
# Now let's have some fun 🚀

# %%
from IPython.display import Markdown, display

def rainbow_text(text):
    colors = ['red', 'orange', 'gold', 'green', 'lightblue', 'yellow', 'violet']
    result = ' '.join(
        f'<span style="color:{c}; font-weight:bold;">{ch}</span>'
        for ch, c in zip(text, colors * (len(text)//len(colors)+1))
    )
    display(Markdown(result))

rainbow_text("Well Done! You've Cloned This Repo!")
# Out:
# <span style="color:red; font-weight:bold;">W</span> <span style="color:orange; font-weight:bold;">e</span> <span style="color:gold; font-weight:bold;">l</span> <span style="color:green; font-weight:bold;">l</span> <span style="color:lightblue; font-weight:bold;"> </span> <span style="color:yellow; font-weight:bold;">D</span> <span style="color:violet; font-weight:bold;">o</span> <span style="color:red; font-weight:bold;">n</span> <span style="color:orange; font-weight:bold;">e</span> <span style="color:gold; font-weight:bold;">!</span> <span style="color:green; font-weight:bold;"> </span> <span style="color:lightblue; font-weight:bold;">Y</span> <span style="color:yellow; font-weight:bold;">o</span> <span style="color:violet; font-weight:bold;">u</span> <span style="color:red; font-weight:bold;">'</span> <span style="color:orange; font-weight:bold;">v</span> <span style="color:gold; font-weight:bold;">e</span> <span style="color:green; font-weight:bold;"> </span> <span style="color:l
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

theta = np.linspace(0, 6*np.pi, 1000)
r = theta**0.5
x = r * np.cos(theta)
y = r * np.sin(theta)

plt.figure(figsize=(6,6))
plt.scatter(x, y, c=theta, cmap='plasma', s=5)
plt.axis('off')
plt.title("✨ Repo Clone Spiral ✨", fontsize=16, fontweight='bold')
plt.show()
# Out:
# /opt/anaconda3/envs/vizsafe311/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 10024 (\N{SPARKLES}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ## 🌟 Next Steps
# - Edit files
# - Commit changes
# - Push to GitHub
#
# You're all set up!
